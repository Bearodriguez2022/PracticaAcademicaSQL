# %%
print('hola exito')
# Out:
# hola exito

# %%
import requests
import pandas as pd

# %%
url = 'https://data.buenosaires.gob.ar/dataset/oferta-establecimientos-gastronomicos'
#url = 'https://data.buenosaires.gob.ar/dataset/tu_dataset/aquí'
response = requests.get(url)

# Verifica si la solicitud fue exitosa (código de estado 200)
if response.status_code == 200:
    # Guarda el contenido de la respuesta en un archivo
    with open('oferta_gastronomica.csv', 'wb') as f:
        f.write(response.content)
    print('Descarga exitosa')
else:
    print('Error al descargar:', response.status_code)
# Out:
# Descarga exitosa

# %%
gastronomia = pd.read_csv(r'C:\Users\Usuario\OneDrive\Escritorio\PracticaAcademica\SQL\Oferta Gastronómica\oferta_gastronomica.csv')

# %%
gastronomia.head()
# Out:
#                                                 long        lat      id  \
# 0  -58.3633067544777,-34.6229634698018,1602,GUANT...        NaN     NaN
# 1                                  -58.3923296263654 -34.621554   676.0
# 2                                  -58.4535422659946 -34.560311   487.0
# 3                                  -58.4754910533597 -34.677051  2737.0
# 4  -58.4254372025985,-34.5856950120038,2,4 EN 2 I...        NaN     NaN
#
#             nombre    categoria       cocina     ambientacion   telefono mail  \
# 0              NaN          NaN          NaN              NaN        NaN  NaN
# 1  1843 VINACOTECA      VINERIA          NaN              NaN  4779 0806  NaN
# 2     2080 EXPRESS  RESTAURANTE  TRADICIONAL  CLASICO PORTEÑO  4788 4500  NaN
# 3               22         CAFE      MINUTAS          MODERNO        NaN  NaN
# 4              NaN          NaN          NaN              NaN        NaN  NaN
#
# ...
